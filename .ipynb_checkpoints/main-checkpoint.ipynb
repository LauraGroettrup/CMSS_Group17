# %%
from mesa import Model, Agent
from mesa.datacollection import DataCollector
from mesa.time import SimultaneousActivation
import numpy as np
import matplotlib.pyplot as plt


class SmallWorldAgentBasic(Agent):

    def __init__(self, unique_id, neighbors,  model):
        '''
         Create a new small world agent.

         Args:
            unique_id: Unique identifier for the agent
            neighbors: list of directly reachable agents
        '''

        super().__init__(unique_id, model)
        self.neighbors = neighbors

        self.infected = False
        self.newly_infected = False
        self.dead = False
        self.candidate_infections = []

    def step(self):
        '''
        Run one step of the agent.
        '''
        self.candidate_infections = []
        if self.dead:
            return

        if self.newly_infected:
            self.infected = True

        if self.infected:
            for neighbor in self.neighbors:
                if self.model.random.random() < self.model.infect_probability:
                    self.candidate_infections.append(neighbor)

    def advance(self):
        '''
        advance step of model
        '''

        if self.dead:
            return

        if self.infected:
            for candidate in self.candidate_infections:
                candidate.newly_infected = True
                print("Agent "+str(candidate.unique_id)+" got infected.\n")
            self.dead = True
            print("Agent "+str(self.unique_id)+" died.\n")

# %%
class SmallWorldModel(Model):

    def __init__(self, N, k, p, r):
        '''
        Create a new small world model.

         Args:
            N: how many agents the model contains
            k: how many neighbors an agent has CURRENTLY ONLY EVEN K SUPPORTED
            p: probability of rearranging edge in initialization
            r: probability of infecting another agent
        '''

        super().__init__()

        # 1 Initialization
        self.num_agents = N
        self.num_neighbors = k
        self.swap_probability = p
        self.infect_probability = r

        self.schedule = SimultaneousActivation(self)
        
        self.datacollector = DataCollector(
            agent_reporters={"Infected": "infected"}
        )
        
        # Create agents
        for i in range(self.num_agents):
            agent = SmallWorldAgentBasic(i, [0]*k, self)
            self.schedule.add(agent)

        agents = self.schedule.agents
        

        # make the k nearest neighbors the official neighbors
        for j in range(int(self.num_neighbors / 2)):
            for i in range(self.num_agents):
                right = (i + j + 1) % self.num_agents
                left = (i - j - 1) % self.num_agents
                agents[i].neighbors[j*2] = agents[right]
                agents[i].neighbors[j*2+1] = agents[left]

        # randomly replace neighbors with new neighbors
        for j in range(self.num_neighbors):
            for i in range(self.num_agents):
                if self.random.random() < self.swap_probability:
                    candidate_agent = self.random.choice(self.schedule.agents)
                    already_connected = True
                    while already_connected:
                        in_neighbors = False
                        for neighbor in agents[i].neighbors:
                            if neighbor == candidate_agent:
                                in_neighbors = True
                        if in_neighbors:
                            candidate_agent = self.random.choice(self.schedule.agents)
                            already_connected = True
                        else:
                            already_connected = False
                    agents[i].neighbors[j] = candidate_agent
                    print("Agent "+str(i)+"'s new Neighbor on position "+str(j)+" is now Agent "+str(candidate_agent.unique_id)+".\n")

        # infect 1 agent
        patient_zero = self.random.choice(self.schedule.agents)
        patient_zero.infected = True
        print("Agent " + str(patient_zero.unique_id) + " got infected.\n")



    def step(self):
        '''
        Run one step of the model. If All agents are happy, halt the model.
        '''

        # 3 Step model function
        self.datacollector.collect(self)
        self.schedule.step()

# %%
model = SmallWorldModel(100, 4, 0.2, 0.5)
while model.schedule.steps < 100:
    model.step()
# Out:
# Agent 20's new Neighbor on position 0 is now Agent 82.
#
# Agent 21's new Neighbor on position 0 is now Agent 68.
#
# Agent 26's new Neighbor on position 0 is now Agent 13.
#
# Agent 27's new Neighbor on position 0 is now Agent 88.
#
# Agent 36's new Neighbor on position 0 is now Agent 23.
#
# Agent 38's new Neighbor on position 0 is now Agent 14.
#
# Agent 41's new Neighbor on position 0 is now Agent 46.
#
# Agent 43's new Neighbor on position 0 is now Agent 50.
#
# Agent 46's new Neighbor on position 0 is now Agent 99.
#
# Agent 53's new Neighbor on position 0 is now Agent 42.
#
# Agent 55's new Neighbor on position 0 is now Agent 98.
#
# Agent 60's new Neighbor on position 0 is now Agent 47.
#
# Agent 62's new Neighbor on position 0 is now Agent 46.
#
# Agent 71's new Neighbor on position 0 is now Agent 53.
#
# Agent 82's new Neighbor on position 0 is now Agent 33.
#
# Agent 84's new Neighbor on position 0 is now Agent 62.
#
# Agent 86's new Neighbor on position 0 is now Agent 64.
#
# Agent 87's new Neighbor on position 0 is now Agent 94.
#
# Agent 99's new Neighbor on position 0 is now Agent 55.
#
# Agent 5's new Neighbor on position 1 is now Agent 59.
#
# Agent 8's new Neighbor on position 1 is now Agent 44.
#
# Agent 9's new Neighbor on position 1 is now Agent 61.
#
# Agent 12's new Neighbor on position 1 is now Agent 24.
#
# Agent 26's new Neighbor on position 1 is now Agent 93.
#
# Agent 28's new Neighbor on position 1 is now Agent 58.
#
# Agent 30's new Neighbor on position 1 is now Agent 86.
#
# Agent 41's new Neighbor on position 1 is now Agent 71.
#
# Agent 43's new Neighbor on position 1 is now Agent 58.
#
# Agent 47's new Neighbor on position 1 is now Agent 85.
#
# Agent 59's new Neighbor on position 1 is now Agent 67.
#
# Agent 63's new Neighbor on position 1 is now Agent 16.
#
# Agent 72's new Neighbor on position 1 is now Agent 3.
#
# Agent 75's new Neighbor on position 1 is now Agent 60.
#
# Agent 76's new Neighbor on position 1 is now Agent 35.
#
# Agent 84's new Neighbor on position 1 is now Agent 66.
#
# Agent 89's new Neighbor on position 1 is now Agent 1.
#
# Agent 91's new Neighbor on position 1 is now Agent 9.
#
# Agent 96's new Neighbor on position 1 is now Agent 48.
#
# Agent 1's new Neighbor on position 2 is now Agent 74.
#
# Agent 4's new Neighbor on position 2 is now Agent 34.
#
# Agent 10's new Neighbor on position 2 is now Agent 54.
#
# Agent 12's new Neighbor on position 2 is now Agent 61.
#
# Agent 30's new Neighbor on position 2 is now Agent 43.
#
# Agent 32's new Neighbor on position 2 is now Agent 13.
#
# Agent 48's new Neighbor on position 2 is now Agent 26.
#
# Agent 55's new Neighbor on position 2 is now Agent 74.
#
# Agent 61's new Neighbor on position 2 is now Agent 40.
#
# Agent 71's new Neighbor on position 2 is now Agent 18.
#
# Agent 74's new Neighbor on position 2 is now Agent 87.
#
# Agent 81's new Neighbor on position 2 is now Agent 6.
#
# Agent 85's new Neighbor on position 2 is now Agent 51.
#
# Agent 86's new Neighbor on position 2 is now Agent 97.
#
# Agent 5's new Neighbor on position 3 is now Agent 55.
#
# Agent 10's new Neighbor on position 3 is now Agent 50.
#
# Agent 12's new Neighbor on position 3 is now Agent 22.
#
# Agent 17's new Neighbor on position 3 is now Agent 28.
#
# Agent 20's new Neighbor on position 3 is now Agent 94.
#
# Agent 21's new Neighbor on position 3 is now Agent 11.
#
# Agent 23's new Neighbor on position 3 is now Agent 61.
#
# Agent 28's new Neighbor on position 3 is now Agent 36.
#
# Agent 34's new Neighbor on position 3 is now Agent 84.
#
# Agent 50's new Neighbor on position 3 is now Agent 45.
#
# Agent 59's new Neighbor on position 3 is now Agent 39.
#
# Agent 61's new Neighbor on position 3 is now Agent 95.
#
# Agent 72's new Neighbor on position 3 is now Agent 58.
#
# Agent 73's new Neighbor on position 3 is now Agent 61.
#
# Agent 81's new Neighbor on position 3 is now Agent 46.
#
# Agent 87's new Neighbor on position 3 is now Agent 64.
#
# Agent 99's new Neighbor on position 3 is now Agent 24.
#
# Agent 65 got infected.
#
# Agent 66 got infected.
#
# Agent 64 got infected.
#
# Agent 65 died.
#
# Agent 62 got infected.
#
# Agent 64 died.
#
# Agent 65 got infected.
#
# Agent 64 got infected.
#
# Agent 66 died.
#
# Agent 61 got infected.
#
# Agent 62 died.
#
# Agent 40 got infected.
#
# Agent 61 died.
#
# Agent 41 got infected.
#
# Agent 39 got infected.
#
# Agent 42 got infected.
#
# Agent 40 died.
#
# Agent 38 got infected.
#
# Agent 41 got infected.
#
# Agent 37 got infected.
#
# Agent 39 died.
#
# Agent 41 died.
#
# Agent 41 got infected.
#
# Agent 42 died.
#
# Agent 36 got infected.
#
# Agent 35 got infected.
#
# Agent 37 died.
#
# Agent 37 got infected.
#
# Agent 40 got infected.
#
# Agent 36 got infected.
#
# Agent 38 died.
#
# Agent 36 got infected.
#
# Agent 34 got infected.
#
# Agent 37 got infected.
#
# Agent 35 died.
#
# Agent 38 got infected.
#
# Agent 36 died.
#
# Agent 35 got infected.
#
# Agent 33 got infected.
#
# Agent 34 died.
#
# Agent 32 got infected.
#
# Agent 31 got infected.
#
# Agent 33 died.
#
# Agent 32 got infected.
#
# Agent 33 got infected.
#
# Agent 31 died.
#
# Agent 33 got infected.
#
# Agent 32 died.

# %%
params = {"N": 100, "k": 4, "p": np.linspace(0.1,1.0,10), "r": 0.5}

# %%
from mesa.batchrunner import batch_run

results = batch_run(
    SmallWorldModel,
    parameters=params,
    iterations= 5,
    max_steps= 100,
    number_processes=1,
    data_collection_period= -1,
    display_progress=True,
)
# Out:
# 59it [00:00, 195.49it/s]
# Agent 8's new Neighbor on position 0 is now Agent 76.
#
# Agent 17's new Neighbor on position 0 is now Agent 56.
#
# Agent 23's new Neighbor on position 0 is now Agent 26.
#
# Agent 32's new Neighbor on position 0 is now Agent 99.
#
# Agent 44's new Neighbor on position 0 is now Agent 97.
#
# Agent 47's new Neighbor on position 0 is now Agent 56.
#
# Agent 59's new Neighbor on position 0 is now Agent 34.
#
# Agent 83's new Neighbor on position 0 is now Agent 58.
#
# Agent 95's new Neighbor on position 0 is now Agent 2.
#
# Agent 98's new Neighbor on position 0 is now Agent 45.
#
# Agent 3's new Neighbor on position 1 is now Agent 88.
#
# Agent 6's new Neighbor on position 1 is now Agent 23.
#
# Agent 13's new Neighbor on position 1 is now Agent 92.
#
# Agent 19's new Neighbor on position 1 is now Agent 62.
#
# Agent 20's new Neighbor on position 1 is now Agent 33.
#
# Agent 28's new Neighbor on position 1 is now Agent 83.
#
# Agent 30's new Neighbor on position 1 is now Agent 11.
#
# Agent 31's new Neighbor on position 1 is now Agent 67.
#
# Agent 40's new Neighbor on position 1 is now Agent 75.
#
# Agent 59's new Neighbor on position 1 is now Agent 63.
#
# Agent 61's new Neighbor on position 1 is now Agent 87.
#
# Agent 63's new Neighbor on position 1 is now Agent 86.
#
# Agent 66's new Neighbor on position 1 is now Agent 23.
#
# Agent 77's new Neighbor on position 1 is now Agent 11.
#
# Agent 79's new Neighbor on position 1 is now Agent 14.
#
# Agent 85's new Neighbor on position 1 is now Agent 15.
#
# Agent 91's new Neighbor on position 1 is now Agent 84.
#
# Agent 93's new Neighbor on position 1 is now Agent 35.
#
# Agent 98's new Neighbor on position 1 is now Agent 14.
#
# Agent 3's new Neighbor on position 2 is now Agent 32.
#
# Agent 4's new Neighbor on position 2 is now Agent 55.
#
# Agent 6's new Neighbor on position 2 is now Agent 62.
#
# Agent 15's new Neighbor on position 2 is now Agent 20.
#
# Agent 17's new Neighbor on position 2 is now Agent 52.
#
# Agent 25's new Neighbor on position 2 is now Agent 74.
#
# Agent 36's new Neighbor on position 2 is now Agent 18.
#
# Agent 40's new Neighbor on position 2 is now Agent 92.
#
# Agent 49's new Neighbor on position 2 is now Agent 13.
#
# Agent 64's new Neighbor on position 2 is now Agent 76.
#
# Agent 67's new Neighbor on position 2 is now Agent 79.
#
# Agent 88's new Neighbor on position 2 is now Agent 30.
#
# Agent 4's new Neighbor on position 3 is now Agent 90.
#
# Agent 15's new Neighbor on position 3 is now Agent 8.
#
# Agent 21's new Neighbor on position 3 is now Agent 92.
#
# Agent 50's new Neighbor on position 3 is now Agent 25.
#
# Agent 95 got infected.
#
# Agent 94 got infected.
#
# Agent 95 died.
#
# Agent 94 died.
#
# Agent 1's new Neighbor on position 0 is now Agent 57.
#
# Agent 5's new Neighbor on position 0 is now Agent 58.
#
# Agent 8's new Neighbor on position 0 is now Agent 34.
#
# Agent 10's new Neighbor on position 0 is now Agent 66.
#
# Agent 12's new Neighbor on position 0 is now Agent 69.
#
# Agent 15's new Neighbor on position 0 is now Agent 43.
#
# Agent 25's new Neighbor on position 0 is now Agent 58.
#
# Agent 34's new Neighbor on position 0 is now Agent 1.
#
# Agent 42's new Neighbor on position 0 is now Agent 39.
#
# Agent 46's new Neighbor on position 0 is now Agent 26.
#
# Agent 48's new Neighbor on position 0 is now Agent 34.
#
# Agent 54's new Neighbor on position 0 is now Agent 49.
#
# Agent 60's new Neighbor on position 0 is now Agent 89.
#
# Agent 61's new Neighbor on position 0 is now Agent 32.
#
# Agent 63's new Neighbor on position 0 is now Agent 81.
#
# Agent 65's new Neighbor on position 0 is now Agent 43.
#
# Agent 68's new Neighbor on position 0 is now Agent 36.
#
# Agent 74's new Neighbor on position 0 is now Agent 0.
#
# Agent 76's new Neighbor on position 0 is now Agent 85.
#
# Agent 80's new Neighbor on position 0 is now Agent 20.
#
# Agent 82's new Neighbor on position 0 is now Agent 38.
#
# Agent 89's new Neighbor on position 0 is now Agent 82.
#
# Agent 96's new Neighbor on position 0 is now Agent 17.
#
# Agent 99's new Neighbor on position 0 is now Agent 83.
#
# Agent 1's new Neighbor on position 1 is now Agent 88.
#
# Agent 23's new Neighbor on position 1 is now Agent 43.
#
# Agent 26's new Neighbor on position 1 is now Agent 60.
#
# Agent 30's new Neighbor on position 1 is now Agent 41.
#
# Agent 46's new Neighbor on position 1 is now Agent 17.
#
# Agent 48's new Neighbor on position 1 is now Agent 85.
#
# Agent 56's new Neighbor on position 1 is now Agent 67.
#
# Agent 58's new Neighbor on position 1 is now Agent 21.
#
# Agent 69's new Neighbor on position 1 is now Agent 4.
#
# Agent 77's new Neighbor on position 1 is now Agent 82.
#
# Agent 88's new Neighbor on position 1 is now Agent 63.
#
# Agent 99's new Neighbor on position 1 is now Agent 17.
#
# Agent 0's new Neighbor on position 2 is now Agent 79.
#
# Agent 6's new Neighbor on position 2 is now Agent 3.
#
# Agent 9's new Neighbor on position 2 is now Agent 1.
#
# Agent 30's new Neighbor on position 2 is now Agent 37.
#
# Agent 31's new Neighbor on position 2 is now Agent 99.
#
# Agent 32's new Neighbor on position 2 is now Agent 11.
#
# Agent 34's new Neighbor on position 2 is now Agent 37.
#
# Agent 46's new Neighbor on position 2 is now Agent 97.
#
# Agent 49's new Neighbor on position 2 is now Agent 21.
#
# Agent 51's new Neighbor on position 2 is now Agent 37.
#
# Agent 58's new Neighbor on position 2 is now Agent 0.
#
# Agent 59's new Neighbor on position 2 is now Agent 76.
#
# Agent 62's new Neighbor on position 2 is now Agent 86.
#
# Agent 70's new Neighbor on position 2 is now Agent 49.
#
# Agent 78's new Neighbor on position 2 is now Agent 35.
#
# Agent 79's new Neighbor on position 2 is now Agent 56.
#
# Agent 89's new Neighbor on position 2 is now Agent 23.
#
# Agent 9's new Neighbor on position 3 is now Agent 54.
#
# Agent 17's new Neighbor on position 3 is now Agent 48.
#
# Agent 23's new Neighbor on position 3 is now Agent 64.
#
# Agent 26's new Neighbor on position 3 is now Agent 40.
#
# Agent 28's new Neighbor on position 3 is now Agent 6.
#
# Agent 29's new Neighbor on position 3 is now Agent 91.
#
# Agent 30's new Neighbor on position 3 is now Agent 12.
#
# Agent 37's new Neighbor on position 3 is now Agent 70.
#
# Agent 38's new Neighbor on position 3 is now Agent 60.
#
# Agent 40's new Neighbor on position 3 is now Agent 71.
#
# Agent 45's new Neighbor on position 3 is now Agent 22.
#
# Agent 47's new Neighbor on position 3 is now Agent 38.
#
# Agent 53's new Neighbor on position 3 is now Agent 13.
#
# Agent 60's new Neighbor on position 3 is now Agent 27.
#
# Agent 71's new Neighbor on position 3 is now Agent 40.
#
# Agent 75's new Neighbor on position 3 is now Agent 15.
#
# Agent 83's new Neighbor on position 3 is now Agent 24.
#
# Agent 85's new Neighbor on position 3 is now Agent 12.
#
# Agent 86's new Neighbor on position 3 is now Agent 3.
#
# Agent 98's new Neighbor on position 3 is now Agent 36.
#
# Agent 20 got infected.
#
# Agent 21 got infected.
#
# Agent 20 died.
#
# Agent 20 got infected.
#
# Agent 19 got infected.
#
# Agent 21 died.
#
# Agent 21 got infected.
#
# Agent 19 died.
#
# Agent 0's new Neighbor on position 0 is now Agent 33.
#
# Agent 3's new Neighbor on position 0 is now Agent 20.
#
# Agent 6's new Neighbor on position 0 is now Agent 77.
#
# Agent 7's new Neighbor on position 0 is now Agent 27.
#
# Agent 9's new Neighbor on position 0 is now Agent 63.
#
# Agent 11's new Neighbor on position 0 is now Agent 74.
#
# Agent 13's new Neighbor on position 0 is now Agent 20.
#
# Agent 15's new Neighbor on position 0 is now Agent 37.
#
# Agent 18's new Neighbor on position 0 is now Agent 10.
#
# Agent 19's new Neighbor on position 0 is now Agent 46.
#
# Agent 23's new Neighbor on position 0 is now Agent 41.
#
# Agent 30's new Neighbor on position 0 is now Agent 14.
#
# Agent 31's new Neighbor on position 0 is now Agent 49.
#
# Agent 32's new Neighbor on position 0 is now Agent 50.
#
# Agent 33's new Neighbor on position 0 is now Agent 98.
#
# Agent 34's new Neighbor on position 0 is now Agent 64.
#
# Agent 40's new Neighbor on position 0 is now Agent 99.
#
# Agent 46's new Neighbor on position 0 is now Agent 5.
#
# Agent 47's new Neighbor on position 0 is now Agent 80.
#
# Agent 52's new Neighbor on position 0 is now Agent 66.
#
# Agent 56's new Neighbor on position 0 is now Agent 66.
#
# Agent 61's new Neighbor on position 0 is now Agent 30.
#
# Agent 63's new Neighbor on position 0 is now Agent 60.
#
# Agent 69's new Neighbor on position 0 is now Agent 30.
#
# Agent 78's new Neighbor on position 0 is now Agent 99.
#
# Agent 79's new Neighbor on position 0 is now Agent 32.
#
# Agent 81's new Neighbor on position 0 is now Agent 71.
#
# Agent 83's new Neighbor on position 0 is now Agent 88.
#
# Agent 85's new Neighbor on position 0 is now Agent 53.
#
# Agent 86's new Neighbor on position 0 is now Agent 51.
#
# Agent 90's new Neighbor on position 0 is now Agent 46.
#
# Agent 98's new Neighbor on position 0 is now Agent 42.
#
# Agent 3's new Neighbor on position 1 is now Agent 87.
#
# Agent 7's new Neighbor on position 1 is now Agent 22.
#
# Agent 9's new Neighbor on position 1 is now Agent 97.
#
# Agent 16's new Neighbor on position 1 is now Agent 27.
#
# Agent 17's new Neighbor on position 1 is now Agent 41.
#
# Agent 24's new Neighbor on position 1 is now Agent 24.
#
# Agent 26's new Neighbor on position 1 is now Agent 95.
#
# Agent 32's new Neighbor on position 1 is now Agent 33.
#
# Agent 35's new Neighbor on position 1 is now Agent 73.
#
# Agent 37's new Neighbor on position 1 is now Agent 60.
#
# Agent 45's new Neighbor on position 1 is now Agent 69.
#
# Agent 52's new Neighbor on position 1 is now Agent 60.
#
# Agent 53's new Neighbor on position 1 is now Agent 9.
#
# Agent 61's new Neighbor on position 1 is now Agent 70.
#
# Agent 64's new Neighbor on position 1 is now Agent 1.
#
# Agent 69's new Neighbor on position 1 is now Agent 23.
#
# Agent 75's new Neighbor on position 1 is now Agent 52.
#
# Agent 82's new Neighbor on position 1 is now Agent 0.
#
# Agent 85's new Neighbor on position 1 is now Agent 19.
#
# Agent 88's new Neighbor on position 1 is now Agent 40.
#
# Agent 89's new Neighbor on position 1 is now Agent 41.
#
# Agent 90's new Neighbor on position 1 is now Agent 40.
#
# Agent 91's new Neighbor on position 1 is now Agent 40.
#
# Agent 94's new Neighbor on position 1 is now Agent 8.
#
# Agent 98's new Neighbor on position 1 is now Agent 68.
#
# Agent 0's new Neighbor on position 2 is now Agent 16.
#
# Agent 1's new Neighbor on position 2 is now Agent 54.
#
# Agent 3's new Neighbor on position 2 is now Agent 36.
#
# Agent 9's new Neighbor on position 2 is now Agent 40.
#
# Agent 11's new Neighbor on position 2 is now Agent 38.
#
# Agent 12's new Neighbor on position 2 is now Agent 35.
#
# Agent 14's new Neighbor on position 2 is now Agent 19.
#
# Agent 15's new Neighbor on position 2 is now Agent 32.
#
# Agent 16's new Neighbor on position 2 is now Agent 2.
#
# Agent 18's new Neighbor on position 2 is now Agent 28.
#
# Agent 19's new Neighbor on position 2 is now Agent 0.
#
# Agent 20's new Neighbor on position 2 is now Agent 44.
#
# Agent 21's new Neighbor on position 2 is now Agent 30.
#
# Agent 23's new Neighbor on position 2 is now Agent 20.
#
# Agent 25's new Neighbor on position 2 is now Agent 62.
#
# Agent 26's new Neighbor on position 2 is now Agent 71.
#
# Agent 31's new Neighbor on position 2 is now Agent 70.
#
# Agent 35's new Neighbor on position 2 is now Agent 68.
#
# Agent 51's new Neighbor on position 2 is now Agent 64.
#
# Agent 62's new Neighbor on position 2 is now Agent 49.
#
# Agent 67's new Neighbor on position 2 is now Agent 51.
#
# Agent 68's new Neighbor on position 2 is now Agent 12.
#
# Agent 73's new Neighbor on position 2 is now Agent 4.
#
# Agent 78's new Neighbor on position 2 is now Agent 69.
#
# Agent 79's new Neighbor on position 2 is now Agent 99.
#
# Agent 80's new Neighbor on position 2 is now Agent 9.
#
# Agent 83's new Neighbor on position 2 is now Agent 80.
#
# Agent 4's new Neighbor on position 3 is now Agent 71.
#
# Agent 5's new Neighbor on position 3 is now Agent 26.
#
# Agent 6's new Neighbor on position 3 is now Agent 57.
#
# Agent 13's new Neighbor on position 3 is now Agent 75.
#
# Agent 18's new Neighbor on position 3 is now Agent 44.
#
# Agent 24's new Neighbor on position 3 is now Agent 13.
#
# Agent 26's new Neighbor on position 3 is now Agent 68.
#
# Agent 31's new Neighbor on position 3 is now Agent 94.
#
# Agent 38's new Neighbor on position 3 is now Agent 1.
#
# Agent 40's new Neighbor on position 3 is now Agent 0.
#
# Agent 42's new Neighbor on position 3 is now Agent 46.
#
# Agent 43's new Neighbor on position 3 is now Agent 71.
#
# Agent 44's new Neighbor on position 3 is now Agent 58.
#
# Agent 45's new Neighbor on position 3 is now Agent 2.
#
# Agent 47's new Neighbor on position 3 is now Agent 70.
#
# Agent 49's new Neighbor on position 3 is now Agent 65.
#
# Agent 54's new Neighbor on position 3 is now Agent 18.
#
# Agent 56's new Neighbor on position 3 is now Agent 14.
#
# Agent 57's new Neighbor on position 3 is now Agent 15.
#
# Agent 59's new Neighbor on position 3 is now Agent 47.
#
# Agent 60's new Neighbor on position 3 is now Agent 43.
#
# Agent 68's new Neighbor on position 3 is now Agent 57.
#
# Agent 71's new Neighbor on position 3 is now Agent 1.
#
# Agent 75's new Neighbor on position 3 is now Agent 97.
#
# Agent 80's new Neighbor on position 3 is now Agent 35.
#
# Agent 81's new Neighbor on position 3 is now Agent 24.
#
# Agent 82's new Neighbor on position 3 is now Agent 89.
#
# Agent 90's new Neighbor on position 3 is now Agent 25.
#
# Agent 96's new Neighbor on position 3 is now Agent 40.
#
# Agent 97's new Neighbor on position 3 is now Agent 38.
#
# Agent 47 got infected.
#
# Agent 80 got infected.
#
# Agent 46 got infected.
#
# Agent 49 got infected.
#
# Agent 47 died.
#
# Agent 45 got infected.
#
# Agent 44 got infected.
#
# Agent 46 died.
#
# Agent 50 got infected.
#
# Agent 48 got infected.
#
# Agent 49 died.
#
# Agent 81 got infected.
#
# Agent 79 got infected.
#
# Agent 35 got infected.
#
# Agent 80 died.
#
# Agent 36 got infected.
#
# Agent 68 got infected.
#
# Agent 33 got infected.
#
# Agent 35 died.
#
# Agent 46 got infected.
#
# Agent 44 died.
#
# Agent 46 got infected.
#
# Agent 69 got infected.
#
# Agent 2 got infected.
#
# Agent 45 died.
#
# Agent 49 got infected.
#
# Agent 47 got infected.
#
# Agent 46 got infected.
#
# Agent 48 died.
#
# Agent 49 got infected.
#
# Agent 52 got infected.
#
# Agent 48 got infected.
#
# Agent 50 died.
#
# Agent 32 got infected.
#
# Agent 78 got infected.
#
# Agent 99 got infected.
#
# Agent 77 got infected.
#
# Agent 79 died.
#
# Agent 80 got infected.
#
# Agent 24 got infected.
#
# Agent 81 died.
#
# Agent 0 got infected.
#
# Agent 2 died.
#
# Agent 24 got infected.
#
# Agent 24 died.
#
# Agent 50 got infected.
#
# Agent 30 got infected.
#
# Agent 32 died.
#
# Agent 98 got infected.
#
# Agent 32 got infected.
#
# Agent 35 got infected.
#
# Agent 31 got infected.
#
# Agent 33 died.
#
# Agent 37 got infected.
#
# Agent 35 got infected.
#
# Agent 36 died.
#
# Agent 50 got infected.
#
# Agent 52 died.
#
# Agent 67 got infected.
#
# Agent 12 got infected.
#
# Agent 57 got infected.
#
# Agent 68 died.
#
# Agent 30 got infected.
#
# Agent 23 got infected.
#
# Agent 71 got infected.
#
# Agent 67 got infected.
#
# Agent 69 died.
#
# Agent 76 got infected.
#
# Agent 77 died.
#
# Agent 77 got infected.
#
# Agent 78 died.
#
# Agent 0 got infected.
#
# Agent 98 got infected.
#
# Agent 1 got infected.
#
# Agent 97 got infected.
#
# Agent 99 died.
#
# Agent 99 got infected.
#
# Agent 98 got infected.
#
# Agent 0 died.
#
# Agent 0 got infected.
#
# Agent 99 got infected.
#
# Agent 1 died.
#
# Agent 35 got infected.
#
# Agent 12 died.
#
# Agent 41 got infected.
#
# Agent 21 got infected.
#
# Agent 23 died.
#
# Agent 29 got infected.
#
# Agent 28 got infected.
#
# Agent 30 died.
#
# Agent 70 got infected.
#
# Agent 31 died.
#
# Agent 38 got infected.
#
# Agent 35 got infected.
#
# Agent 37 died.
#
# Agent 56 got infected.
#
# Agent 15 got infected.
#
# Agent 57 died.
#
# Agent 67 died.
#
# Agent 72 got infected.
#
# Agent 73 got infected.
#
# Agent 71 died.
#
# Agent 76 died.
#
# Agent 98 got infected.
#
# Agent 99 got infected.
#
# Agent 97 died.
#
# Agent 42 got infected.
#
# Agent 68 got infected.
#
# Agent 96 got infected.
#
# Agent 98 died.
#
# Agent 37 got infected.
#
# Agent 13 got infected.
#
# Agent 15 died.
#
# Agent 20 got infected.
#
# Agent 21 died.
#
# Agent 29 got infected.
#
# Agent 30 got infected.
#
# Agent 26 got infected.
#
# Agent 28 died.
#
# Agent 30 got infected.
#
# Agent 28 got infected.
#
# Agent 27 got infected.
#
# Agent 29 died.
#
# Agent 39 got infected.
#
# Agent 40 got infected.
#
# Agent 38 died.
#
# Agent 40 got infected.
#
# Agent 43 got infected.
#
# Agent 41 died.
#
# Agent 41 got infected.
#
# Agent 46 got infected.
#
# Agent 42 died.
#
# Agent 66 got infected.
#
# Agent 55 got infected.
#
# Agent 56 died.
#
# Agent 71 got infected.
#
# Agent 72 got infected.
#
# Agent 70 died.
#
# Agent 71 got infected.
#
# Agent 74 got infected.
#
# Agent 70 got infected.
#
# Agent 72 died.
#
# Agent 72 got infected.
#
# Agent 71 got infected.
#
# Agent 73 died.
#
# Agent 40 got infected.
#
# Agent 96 died.
#
# Agent 20 got infected.
#
# Agent 12 got infected.
#
# Agent 13 died.
#
# Agent 21 got infected.
#
# Agent 19 got infected.
#
# Agent 44 got infected.
#
# Agent 18 got infected.
#
# Agent 20 died.
#
# Agent 27 got infected.
#
# Agent 26 died.
#
# Agent 28 got infected.
#
# Agent 26 got infected.
#
# Agent 29 got infected.
#
# Agent 27 died.
#
# Agent 37 got infected.
#
# Agent 39 died.
#
# Agent 39 got infected.
#
# Agent 42 got infected.
#
# Agent 0 got infected.
#
# Agent 40 died.
#
# Agent 44 got infected.
#
# Agent 71 got infected.
#
# Agent 43 died.
#
# Agent 54 got infected.
#
# Agent 55 died.
#
# Agent 67 got infected.
#
# Agent 65 got infected.
#
# Agent 68 got infected.
#
# Agent 66 died.
#
# Agent 75 got infected.
#
# Agent 73 got infected.
#
# Agent 76 got infected.
#
# Agent 72 got infected.
#
# Agent 74 died.
#
# Agent 17 got infected.
#
# Agent 28 got infected.
#
# Agent 18 died.
#
# Agent 46 got infected.
#
# Agent 0 got infected.
#
# Agent 17 got infected.
#
# Agent 19 died.
#
# Agent 55 got infected.
#
# Agent 54 died.
#
# Agent 64 got infected.
#
# Agent 65 died.
#
# Agent 52 got infected.
#
# Agent 97 got infected.
#
# Agent 75 died.
#
# Agent 41 got infected.
#
# Agent 17 died.
#
# Agent 65 got infected.
#
# Agent 66 got infected.
#
# Agent 62 got infected.
#
# Agent 64 died.
#
# Agent 61 got infected.
#
# Agent 49 got infected.
#
# Agent 60 got infected.
#
# Agent 62 died.
#
# Agent 59 got infected.
#
# Agent 62 got infected.
#
# Agent 60 died.
#
# Agent 63 got infected.
#
# Agent 61 died.
#
# Agent 60 got infected.
#
# Agent 61 got infected.
#
# Agent 47 got infected.
#
# Agent 59 died.
#
# Agent 60 got infected.
#
# Agent 65 got infected.
#
# Agent 61 got infected.
#
# Agent 63 died.
#
# Agent 2's new Neighbor on position 0 is now Agent 60.
#
# Agent 5's new Neighbor on position 0 is now Agent 47.
#
# Agent 7's new Neighbor on position 0 is now Agent 33.
#
# Agent 8's new Neighbor on position 0 is now Agent 1.
#
# Agent 11's new Neighbor on position 0 is now Agent 75.
#
# Agent 12's new Neighbor on position 0 is now Agent 75.
#
# Agent 13's new Neighbor on position 0 is now Agent 88.
#
# Agent 15's new Neighbor on position 0 is now Agent 92.
#
# Agent 16's new Neighbor on position 0 is now Agent 43.
#
# Agent 17's new Neighbor on position 0 is now Agent 9.
#
# Agent 20's new Neighbor on position 0 is now Agent 67.
#
# Agent 23's new Neighbor on position 0 is now Agent 83.
#
# Agent 25's new Neighbor on position 0 is now Agent 50.
#
# Agent 26's new Neighbor on position 0 is now Agent 92.
#
# Agent 27's new Neighbor on position 0 is now Agent 17.
#
# Agent 30's new Neighbor on position 0 is now Agent 58.
#
# Agent 36's new Neighbor on position 0 is now Agent 89.
#
# Agent 38's new Neighbor on position 0 is now Agent 70.
#
# Agent 40's new Neighbor on position 0 is now Agent 84.
#
# Agent 45's new Neighbor on position 0 is now Agent 63.
#
# Agent 46's new Neighbor on position 0 is now Agent 6.
#
# Agent 47's new Neighbor on position 0 is now Agent 68.
#
# Agent 56's new Neighbor on position 0 is now Agent 39.
#
# Agent 59's new Neighbor on position 0 is now Agent 39.
#
# Agent 60's new Neighbor on position 0 is now Agent 54.
#
# Agent 61's new Neighbor on position 0 is now Agent 22.
#
# Agent 62's new Neighbor on position 0 is now Agent 84.
#
# Agent 63's new Neighbor on position 0 is now Agent 80.
#
# Agent 66's new Neighbor on position 0 is now Agent 70.
#
# Agent 67's new Neighbor on position 0 is now Agent 34.
#
# Agent 69's new Neighbor on position 0 is now Agent 15.
#
# Agent 70's new Neighbor on position 0 is now Agent 96.
#
# Agent 72's new Neighbor on position 0 is now Agent 64.
#
# Agent 73's new Neighbor on position 0 is now Agent 80.
#
# Agent 74's new Neighbor on position 0 is now Agent 86.
#
# Agent 75's new Neighbor on position 0 is now Agent 97.
#
# Agent 78's new Neighbor on position 0 is now Agent 19.
#
# Agent 79's new Neighbor on position 0 is now Agent 65.
#
# Agent 84's new Neighbor on position 0 is now Agent 93.
#
# Agent 86's new Neighbor on position 0 is now Agent 57.
#
# Agent 88's new Neighbor on position 0 is now Agent 47.
#
# Agent 89's new Neighbor on position 0 is now Agent 6.
#
# Agent 90's new Neighbor on position 0 is now Agent 31.
#
# Agent 94's new Neighbor on position 0 is now Agent 86.
#
# Agent 95's new Neighbor on position 0 is now Agent 18.
#
# Agent 98's new Neighbor on position 0 is now Agent 46.
#
# Agent 0's new Neighbor on position 1 is now Agent 19.
#
# Agent 3's new Neighbor on position 1 is now Agent 66.
#
# Agent 4's new Neighbor on position 1 is now Agent 34.
#
# Agent 5's new Neighbor on position 1 is now Agent 99.
#
# Agent 6's new Neighbor on position 1 is now Agent 77.
#
# Agent 9's new Neighbor on position 1 is now Agent 13.
#
# Agent 10's new Neighbor on position 1 is now Agent 18.
#
# Agent 13's new Neighbor on position 1 is now Agent 53.
#
# Agent 15's new Neighbor on position 1 is now Agent 52.
#
# Agent 17's new Neighbor on position 1 is now Agent 44.
#
# Agent 20's new Neighbor on position 1 is now Agent 0.
#
# Agent 21's new Neighbor on position 1 is now Agent 32.
#
# Agent 26's new Neighbor on position 1 is now Agent 48.
#
# Agent 27's new Neighbor on position 1 is now Agent 97.
#
# Agent 28's new Neighbor on position 1 is now Agent 56.
#
# Agent 32's new Neighbor on position 1 is now Agent 39.
#
# Agent 36's new Neighbor on position 1 is now Agent 85.
#
# Agent 37's new Neighbor on position 1 is now Agent 56.
#
# Agent 38's new Neighbor on position 1 is now Agent 54.
#
# Agent 39's new Neighbor on position 1 is now Agent 50.
#
# Agent 40's new Neighbor on position 1 is now Agent 85.
#
# Agent 45's new Neighbor on position 1 is now Agent 60.
#
# Agent 49's new Neighbor on position 1 is now Agent 98.
#
# Agent 51's new Neighbor on position 1 is now Agent 42.
#
# Agent 52's new Neighbor on position 1 is now Agent 68.
#
# Agent 54's new Neighbor on position 1 is now Agent 35.
#
# Agent 55's new Neighbor on position 1 is now Agent 42.
#
# Agent 56's new Neighbor on position 1 is now Agent 8.
#
# Agent 57's new Neighbor on position 1 is now Agent 84.
#
# Agent 60's new Neighbor on position 1 is now Agent 9.
#
# Agent 61's new Neighbor on position 1 is now Agent 70.
#
# Agent 64's new Neighbor on position 1 is now Agent 58.
#
# Agent 65's new Neighbor on position 1 is now Agent 56.
#
# Agent 66's new Neighbor on position 1 is now Agent 45.
#
# Agent 67's new Neighbor on position 1 is now Agent 4.
#
# Agent 69's new Neighbor on position 1 is now Agent 51.
#
# Agent 70's new Neighbor on position 1 is now Agent 47.
#
# Agent 71's new Neighbor on position 1 is now Agent 29.
#
# Agent 72's new Neighbor on position 1 is now Agent 10.
#
# Agent 76's new Neighbor on position 1 is now Agent 16.
#
# Agent 79's new Neighbor on position 1 is now Agent 17.
#
# Agent 80's new Neighbor on position 1 is now Agent 66.
#
# Agent 81's new Neighbor on position 1 is now Agent 57.
#
# Agent 85's new Neighbor on position 1 is now Agent 39.
#
# Agent 87's new Neighbor on position 1 is now Agent 84.
#
# Agent 89's new Neighbor on position 1 is now Agent 57.
#
# Agent 91's new Neighbor on position 1 is now Agent 25.
#
# Agent 93's new Neighbor on position 1 is now Agent 42.
#
# Agent 96's new Neighbor on position 1 is now Agent 83.
#
# Agent 98's new Neighbor on position 1 is now Agent 51.
#
# Agent 99's new Neighbor on position 1 is now Agent 31.
#
# Agent 0's new Neighbor on position 2 is now Agent 3.
#
# Agent 2's new Neighbor on position 2 is now Agent 87.
#
# Agent 3's new Neighbor on position 2 is now Agent 12.
#
# Agent 4's new Neighbor on position 2 is now Agent 75.
#
# Agent 7's new Neighbor on position 2 is now Agent 89.
#
# Agent 12's new Neighbor on position 2 is now Agent 38.
#
# Agent 14's new Neighbor on position 2 is now Agent 82.
#
# Agent 16's new Neighbor on position 2 is now Agent 99.
#
# Agent 18's new Neighbor on position 2 is now Agent 44.
#
# Agent 19's new Neighbor on position 2 is now Agent 78.
#
# Agent 23's new Neighbor on position 2 is now Agent 5.
#
# Agent 24's new Neighbor on position 2 is now Agent 67.
#
# Agent 26's new Neighbor on position 2 is now Agent 53.
#
# Agent 27's new Neighbor on position 2 is now Agent 13.
#
# Agent 28's new Neighbor on position 2 is now Agent 7.
#
# Agent 32's new Neighbor on position 2 is now Agent 0.
#
# Agent 35's new Neighbor on position 2 is now Agent 9.
#
# Agent 37's new Neighbor on position 2 is now Agent 94.
#
# Agent 41's new Neighbor on position 2 is now Agent 46.
#
# Agent 43's new Neighbor on position 2 is now Agent 95.
#
# Agent 44's new Neighbor on position 2 is now Agent 82.
#
# Agent 46's new Neighbor on position 2 is now Agent 49.
#
# Agent 49's new Neighbor on position 2 is now Agent 58.
#
# Agent 51's new Neighbor on position 2 is now Agent 74.
#
# Agent 59's new Neighbor on position 2 is now Agent 36.
#
# Agent 65's new Neighbor on position 2 is now Agent 98.
#
# Agent 66's new Neighbor on position 2 is now Agent 55.
#
# Agent 70's new Neighbor on position 2 is now Agent 2.
#
# Agent 71's new Neighbor on position 2 is now Agent 61.
#
# Agent 73's new Neighbor on position 2 is now Agent 67.
#
# Agent 74's new Neighbor on position 2 is now Agent 74.
#
# Agent 75's new Neighbor on position 2 is now Agent 34.
#
# Agent 76's new Neighbor on position 2 is now Agent 95.
#
# Agent 79's new Neighbor on position 2 is now Agent 31.
#
# Agent 80's new Neighbor on position 2 is now Agent 85.
#
# Agent 83's new Neighbor on position 2 is now Agent 33.
#
# Agent 87's new Neighbor on position 2 is now Agent 34.
#
# Agent 97's new Neighbor on position 2 is now Agent 22.
#
# Agent 2's new Neighbor on position 3 is now Agent 16.
#
# Agent 5's new Neighbor on position 3 is now Agent 76.
#
# Agent 6's new Neighbor on position 3 is now Agent 91.
#
# Agent 9's new Neighbor on position 3 is now Agent 40.
#
# Agent 13's new Neighbor on position 3 is now Agent 80.
#
# Agent 18's new Neighbor on position 3 is now Agent 48.
#
# Agent 20's new Neighbor on position 3 is now Agent 9.
#
# Agent 21's new Neighbor on position 3 is now Agent 70.
#
# Agent 22's new Neighbor on position 3 is now Agent 59.
#
# Agent 25's new Neighbor on position 3 is now Agent 90.
#
# Agent 28's new Neighbor on position 3 is now Agent 59.
#
# Agent 29's new Neighbor on position 3 is now Agent 63.
#
# Agent 32's new Neighbor on position 3 is now Agent 7.
#
# Agent 33's new Neighbor on position 3 is now Agent 55.
#
# Agent 34's new Neighbor on position 3 is now Agent 58.
#
# Agent 40's new Neighbor on position 3 is now Agent 68.
#
# Agent 41's new Neighbor on position 3 is now Agent 35.
#
# Agent 43's new Neighbor on position 3 is now Agent 15.
#
# Agent 48's new Neighbor on position 3 is now Agent 17.
#
# Agent 51's new Neighbor on position 3 is now Agent 23.
#
# Agent 54's new Neighbor on position 3 is now Agent 45.
#
# Agent 57's new Neighbor on position 3 is now Agent 51.
#
# Agent 60's new Neighbor on position 3 is now Agent 69.
#
# Agent 63's new Neighbor on position 3 is now Agent 69.
#
# Agent 65's new Neighbor on position 3 is now Agent 16.
#
# Agent 66's new Neighbor on position 3 is now Agent 1.
#
# Agent 67's new Neighbor on position 3 is now Agent 37.
#
# Agent 71's new Neighbor on position 3 is now Agent 37.
#
# Agent 72's new Neighbor on position 3 is now Agent 30.
#
# Agent 76's new Neighbor on position 3 is now Agent 97.
#
# Agent 79's new Neighbor on position 3 is now Agent 67.
#
# Agent 82's new Neighbor on position 3 is now Agent 29.
#
# Agent 83's new Neighbor on position 3 is now Agent 78.
#
# Agent 85's new Neighbor on position 3 is now Agent 15.
#
# Agent 87's new Neighbor on position 3 is now Agent 93.
#
# Agent 92's new Neighbor on position 3 is now Agent 85.
#
# Agent 95's new Neighbor on position 3 is now Agent 69.
#
# Agent 99's new Neighbor on position 3 is now Agent 40.
#
# Agent 1 got infected.
#
# Agent 3 got infected.
#
# Agent 99 got infected.
#
# Agent 1 died.
#
# Agent 66 got infected.
#
# Agent 1 got infected.
#
# Agent 3 died.
#
# Agent 0 got infected.
#
# Agent 31 got infected.
#
# Agent 99 died.
#
# Agent 1 got infected.
#
# Agent 19 got infected.
#
# Agent 3 got infected.
#
# Agent 0 died.
#
# Agent 32 got infected.
#
# Agent 31 died.
#
# Agent 70 got infected.
#
# Agent 1 got infected.
#
# Agent 66 died.
#
# Agent 20 got infected.
#
# Agent 18 got infected.
#
# Agent 19 died.
#
# Agent 33 got infected.
#
# Agent 39 got infected.
#
# Agent 32 died.
#
# Agent 96 got infected.
#
# Agent 47 got infected.
#
# Agent 70 died.
#
# Agent 48 got infected.
#
# Agent 18 died.
#
# Agent 0 got infected.
#
# Agent 9 got infected.
#
# Agent 20 died.
#
# Agent 34 got infected.
#
# Agent 32 got infected.
#
# Agent 35 got infected.
#
# Agent 33 died.
#
# Agent 37 got infected.
#
# Agent 39 died.
#
# Agent 68 got infected.
#
# Agent 47 died.
#
# Agent 83 got infected.
#
# Agent 98 got infected.
#
# Agent 96 died.
#
# Agent 13 got infected.
#
# Agent 40 got infected.
#
# Agent 9 died.
#
# Agent 36 got infected.
#
# Agent 34 died.
#
# Agent 36 got infected.
#
# Agent 35 died.
#
# Agent 38 got infected.
#
# Agent 35 got infected.
#
# Agent 37 died.
#
# Agent 47 got infected.
#
# Agent 17 got infected.
#
# Agent 48 died.
#
# Agent 69 got infected.
#
# Agent 67 got infected.
#
# Agent 68 died.
#
# Agent 82 got infected.
#
# Agent 33 got infected.
#
# Agent 78 got infected.
#
# Agent 83 died.
#
# Agent 46 got infected.
#
# Agent 0 got infected.
#
# Agent 98 died.
#
# Agent 88 got infected.
#
# Agent 53 got infected.
#
# Agent 15 got infected.
#
# Agent 80 got infected.
#
# Agent 13 died.
#
# Agent 9 got infected.
#
# Agent 19 got infected.
#
# Agent 17 died.
#
# Agent 89 got infected.
#
# Agent 85 got infected.
#
# Agent 36 died.
#
# Agent 54 got infected.
#
# Agent 36 got infected.
#
# Agent 38 died.
#
# Agent 84 got infected.
#
# Agent 68 got infected.
#
# Agent 40 died.
#
# Agent 46 died.
#
# Agent 69 got infected.
#
# Agent 37 got infected.
#
# Agent 67 died.
#
# Agent 51 got infected.
#
# Agent 69 died.
#
# Agent 19 got infected.
#
# Agent 77 got infected.
#
# Agent 76 got infected.
#
# Agent 78 died.
#
# Agent 81 got infected.
#
# Agent 29 got infected.
#
# Agent 82 died.
#
# Agent 92 got infected.
#
# Agent 13 got infected.
#
# Agent 15 died.
#
# Agent 30 got infected.
#
# Agent 28 got infected.
#
# Agent 29 died.
#
# Agent 42 got infected.
#
# Agent 51 died.
#
# Agent 54 got infected.
#
# Agent 52 got infected.
#
# Agent 55 got infected.
#
# Agent 53 died.
#
# Agent 35 got infected.
#
# Agent 54 died.
#
# Agent 16 got infected.
#
# Agent 97 got infected.
#
# Agent 76 died.
#
# Agent 79 got infected.
#
# Agent 77 died.
#
# Agent 81 got infected.
#
# Agent 85 got infected.
#
# Agent 78 got infected.
#
# Agent 80 died.
#
# Agent 57 got infected.
#
# Agent 81 died.
#
# Agent 93 got infected.
#
# Agent 86 got infected.
#
# Agent 84 died.
#
# Agent 86 got infected.
#
# Agent 39 got infected.
#
# Agent 87 got infected.
#
# Agent 15 got infected.
#
# Agent 85 died.
#
# Agent 47 got infected.
#
# Agent 90 got infected.
#
# Agent 86 got infected.
#
# Agent 88 died.
#
# Agent 6 got infected.
#
# Agent 57 got infected.
#
# Agent 91 got infected.
#
# Agent 89 died.
#
# Agent 77 got infected.
#
# Agent 91 got infected.
#
# Agent 6 died.
#
# Agent 43 got infected.
#
# Agent 99 got infected.
#
# Agent 16 died.
#
# Agent 29 got infected.
#
# Agent 56 got infected.
#
# Agent 59 got infected.
#
# Agent 28 died.
#
# Agent 30 died.
#
# Agent 42 died.
#
# Agent 68 got infected.
#
# Agent 54 got infected.
#
# Agent 50 got infected.
#
# Agent 52 died.
#
# Agent 56 got infected.
#
# Agent 57 got infected.
#
# Agent 55 died.
#
# Agent 84 got infected.
#
# Agent 57 died.
#
# Agent 65 got infected.
#
# Agent 67 got infected.
#
# Agent 79 died.
#
# Agent 88 got infected.
#
# Agent 84 got infected.
#
# Agent 86 died.
#
# Agent 88 got infected.
#
# Agent 93 got infected.
#
# Agent 87 died.
#
# Agent 92 got infected.
#
# Agent 90 died.
#
# Agent 92 got infected.
#
# Agent 89 got infected.
#
# Agent 91 died.
#
# Agent 91 got infected.
#
# Agent 94 got infected.
#
# Agent 85 got infected.
#
# Agent 92 died.
#
# Agent 94 got infected.
#
# Agent 42 got infected.
#
# Agent 91 got infected.
#
# Agent 93 died.
#
# Agent 96 got infected.
#
# Agent 95 got infected.
#
# Agent 97 died.
#
# Agent 44 got infected.
#
# Agent 95 got infected.
#
# Agent 15 got infected.
#
# Agent 43 died.
#
# Agent 49 got infected.
#
# Agent 50 died.
#
# Agent 39 got infected.
#
# Agent 56 died.
#
# Agent 39 got infected.
#
# Agent 36 got infected.
#
# Agent 57 got infected.
#
# Agent 59 died.
#
# Agent 66 got infected.
#
# Agent 56 got infected.
#
# Agent 65 died.
#
# Agent 96 got infected.
#
# Agent 94 died.
#
# Agent 18 got infected.
#
# Agent 95 died.
#
# Agent 45 got infected.
#
# Agent 82 got infected.
#
# Agent 44 died.
#
# Agent 58 got infected.
#
# Agent 49 died.
#
# Agent 45 died.
#
# Agent 59 got infected.
#
# Agent 60 got infected.
#
# Agent 56 got infected.
#
# Agent 58 died.
#
# Agent 54 got infected.
#
# Agent 62 got infected.
#
# Agent 69 got infected.
#
# Agent 60 died.
#
# Agent 61 got infected.
#
# Agent 64 got infected.
#
# Agent 60 got infected.
#
# Agent 62 died.
#
# Agent 22 got infected.
#
# Agent 70 got infected.
#
# Agent 59 got infected.
#
# Agent 61 died.
#
# Agent 64 died.
#
# Agent 23 got infected.
#
# Agent 21 got infected.
#
# Agent 22 died.
#
# Agent 32 got infected.
#
# Agent 21 died.
#
# Agent 83 got infected.
#
# Agent 5 got infected.
#
# Agent 21 got infected.
#
# Agent 23 died.
#
# Agent 47 got infected.
#
# Agent 99 got infected.
#
# Agent 7 got infected.
#
# Agent 76 got infected.
#
# Agent 5 died.
#
# Agent 33 got infected.
#
# Agent 5 got infected.
#
# Agent 7 died.
#
# Agent 2's new Neighbor on position 0 is now Agent 67.
#
# Agent 3's new Neighbor on position 0 is now Agent 73.
#
# Agent 4's new Neighbor on position 0 is now Agent 65.
#
# Agent 7's new Neighbor on position 0 is now Agent 52.
#
# Agent 8's new Neighbor on position 0 is now Agent 58.
#
# Agent 14's new Neighbor on position 0 is now Agent 80.
#
# Agent 16's new Neighbor on position 0 is now Agent 79.
#
# Agent 18's new Neighbor on position 0 is now Agent 85.
#
# Agent 20's new Neighbor on position 0 is now Agent 82.
#
# Agent 23's new Neighbor on position 0 is now Agent 14.
#
# Agent 25's new Neighbor on position 0 is now Agent 64.
#
# Agent 26's new Neighbor on position 0 is now Agent 37.
#
# Agent 27's new Neighbor on position 0 is now Agent 44.
#
# Agent 29's new Neighbor on position 0 is now Agent 75.
#
# Agent 31's new Neighbor on position 0 is now Agent 37.
#
# Agent 37's new Neighbor on position 0 is now Agent 97.
#
# Agent 38's new Neighbor on position 0 is now Agent 22.
#
# Agent 42's new Neighbor on position 0 is now Agent 34.
#
# Agent 44's new Neighbor on position 0 is now Agent 51.
#
# Agent 45's new Neighbor on position 0 is now Agent 1.
#
# Agent 46's new Neighbor on position 0 is now Agent 72.
#
# Agent 47's new Neighbor on position 0 is now Agent 1.
#
# Agent 48's new Neighbor on position 0 is now Agent 75.
#
# Agent 51's new Neighbor on position 0 is now Agent 15.
#
# Agent 53's new Neighbor on position 0 is now Agent 78.
#
# Agent 55's new Neighbor on position 0 is now Agent 17.
#
# Agent 56's new Neighbor on position 0 is now Agent 20.
#
# Agent 57's new Neighbor on position 0 is now Agent 82.
#
# Agent 59's new Neighbor on position 0 is now Agent 14.
#
# Agent 60's new Neighbor on position 0 is now Agent 11.
#
# Agent 67's new Neighbor on position 0 is now Agent 60.
#
# Agent 68's new Neighbor on position 0 is now Agent 45.
#
# Agent 69's new Neighbor on position 0 is now Agent 61.
#
# Agent 70's new Neighbor on position 0 is now Agent 44.
#
# Agent 71's new Neighbor on position 0 is now Agent 94.
#
# Agent 74's new Neighbor on position 0 is now Agent 9.
#
# Agent 76's new Neighbor on position 0 is now Agent 44.
#
# Agent 78's new Neighbor on position 0 is now Agent 3.
#
# Agent 79's new Neighbor on position 0 is now Agent 31.
#
# Agent 81's new Neighbor on position 0 is now Agent 19.
#
# Agent 82's new Neighbor on position 0 is now Agent 32.
#
# Agent 83's new Neighbor on position 0 is now Agent 49.
#
# Agent 84's new Neighbor on position 0 is now Agent 73.
#
# Agent 89's new Neighbor on position 0 is now Agent 38.
#
# Agent 92's new Neighbor on position 0 is now Agent 62.
#
# Agent 98's new Neighbor on position 0 is now Agent 83.
#
# Agent 99's new Neighbor on position 0 is now Agent 52.
#
# Agent 1's new Neighbor on position 1 is now Agent 8.
#
# Agent 2's new Neighbor on position 1 is now Agent 89.
#
# Agent 3's new Neighbor on position 1 is now Agent 24.
#
# Agent 6's new Neighbor on position 1 is now Agent 94.
#
# Agent 7's new Neighbor on position 1 is now Agent 53.
#
# Agent 8's new Neighbor on position 1 is now Agent 34.
#
# Agent 9's new Neighbor on position 1 is now Agent 20.
#
# Agent 11's new Neighbor on position 1 is now Agent 5.
#
# Agent 12's new Neighbor on position 1 is now Agent 78.
#
# Agent 13's new Neighbor on position 1 is now Agent 9.
#
# Agent 14's new Neighbor on position 1 is now Agent 41.
#
# Agent 15's new Neighbor on position 1 is now Agent 55.
#
# Agent 18's new Neighbor on position 1 is now Agent 55.
#
# Agent 19's new Neighbor on position 1 is now Agent 95.
#
# Agent 20's new Neighbor on position 1 is now Agent 97.
#
# Agent 21's new Neighbor on position 1 is now Agent 87.
#
# Agent 28's new Neighbor on position 1 is now Agent 60.
#
# Agent 29's new Neighbor on position 1 is now Agent 83.
#
# Agent 31's new Neighbor on position 1 is now Agent 4.
#
# Agent 34's new Neighbor on position 1 is now Agent 81.
#
# Agent 35's new Neighbor on position 1 is now Agent 32.
#
# Agent 36's new Neighbor on position 1 is now Agent 48.
#
# Agent 37's new Neighbor on position 1 is now Agent 79.
#
# Agent 38's new Neighbor on position 1 is now Agent 44.
#
# Agent 40's new Neighbor on position 1 is now Agent 2.
#
# Agent 41's new Neighbor on position 1 is now Agent 3.
#
# Agent 43's new Neighbor on position 1 is now Agent 70.
#
# Agent 47's new Neighbor on position 1 is now Agent 95.
#
# Agent 52's new Neighbor on position 1 is now Agent 70.
#
# Agent 55's new Neighbor on position 1 is now Agent 70.
#
# Agent 56's new Neighbor on position 1 is now Agent 7.
#
# Agent 57's new Neighbor on position 1 is now Agent 2.
#
# Agent 59's new Neighbor on position 1 is now Agent 43.
#
# Agent 60's new Neighbor on position 1 is now Agent 30.
#
# Agent 63's new Neighbor on position 1 is now Agent 42.
#
# Agent 65's new Neighbor on position 1 is now Agent 83.
#
# Agent 66's new Neighbor on position 1 is now Agent 95.
#
# Agent 68's new Neighbor on position 1 is now Agent 82.
#
# Agent 69's new Neighbor on position 1 is now Agent 66.
#
# Agent 70's new Neighbor on position 1 is now Agent 49.
#
# Agent 72's new Neighbor on position 1 is now Agent 15.
#
# Agent 73's new Neighbor on position 1 is now Agent 56.
#
# Agent 77's new Neighbor on position 1 is now Agent 67.
#
# Agent 78's new Neighbor on position 1 is now Agent 0.
#
# Agent 79's new Neighbor on position 1 is now Agent 92.
#
# Agent 83's new Neighbor on position 1 is now Agent 65.
#
# Agent 87's new Neighbor on position 1 is now Agent 37.
#
# Agent 89's new Neighbor on position 1 is now Agent 50.
#
# Agent 90's new Neighbor on position 1 is now Agent 43.
#
# Agent 92's new Neighbor on position 1 is now Agent 43.
#
# Agent 93's new Neighbor on position 1 is now Agent 52.
#
# Agent 94's new Neighbor on position 1 is now Agent 85.
#
# Agent 95's new Neighbor on position 1 is now Agent 4.
#
# Agent 97's new Neighbor on position 1 is now Agent 43.
#
# Agent 0's new Neighbor on position 2 is now Agent 48.
#
# Agent 3's new Neighbor on position 2 is now Agent 70.
#
# Agent 5's new Neighbor on position 2 is now Agent 62.
#
# Agent 6's new Neighbor on position 2 is now Agent 58.
#
# Agent 7's new Neighbor on position 2 is now Agent 69.
#
# Agent 8's new Neighbor on position 2 is now Agent 82.
#
# Agent 10's new Neighbor on position 2 is now Agent 41.
#
# Agent 13's new Neighbor on position 2 is now Agent 21.
#
# Agent 14's new Neighbor on position 2 is now Agent 49.
#
# Agent 15's new Neighbor on position 2 is now Agent 62.
#
# Agent 16's new Neighbor on position 2 is now Agent 66.
#
# Agent 17's new Neighbor on position 2 is now Agent 94.
#
# Agent 18's new Neighbor on position 2 is now Agent 62.
#
# Agent 19's new Neighbor on position 2 is now Agent 18.
#
# Agent 21's new Neighbor on position 2 is now Agent 96.
#
# Agent 23's new Neighbor on position 2 is now Agent 38.
#
# Agent 26's new Neighbor on position 2 is now Agent 87.
#
# Agent 28's new Neighbor on position 2 is now Agent 87.
#
# Agent 30's new Neighbor on position 2 is now Agent 8.
#
# Agent 32's new Neighbor on position 2 is now Agent 23.
#
# Agent 33's new Neighbor on position 2 is now Agent 87.
#
# Agent 34's new Neighbor on position 2 is now Agent 47.
#
# Agent 35's new Neighbor on position 2 is now Agent 83.
#
# Agent 38's new Neighbor on position 2 is now Agent 14.
#
# Agent 40's new Neighbor on position 2 is now Agent 84.
#
# Agent 41's new Neighbor on position 2 is now Agent 55.
#
# Agent 42's new Neighbor on position 2 is now Agent 89.
#
# Agent 44's new Neighbor on position 2 is now Agent 28.
#
# Agent 45's new Neighbor on position 2 is now Agent 84.
#
# Agent 50's new Neighbor on position 2 is now Agent 62.
#
# Agent 51's new Neighbor on position 2 is now Agent 90.
#
# Agent 53's new Neighbor on position 2 is now Agent 60.
#
# Agent 55's new Neighbor on position 2 is now Agent 60.
#
# Agent 57's new Neighbor on position 2 is now Agent 14.
#
# Agent 58's new Neighbor on position 2 is now Agent 14.
#
# Agent 59's new Neighbor on position 2 is now Agent 77.
#
# Agent 60's new Neighbor on position 2 is now Agent 0.
#
# Agent 61's new Neighbor on position 2 is now Agent 11.
#
# Agent 63's new Neighbor on position 2 is now Agent 10.
#
# Agent 64's new Neighbor on position 2 is now Agent 74.
#
# Agent 65's new Neighbor on position 2 is now Agent 31.
#
# Agent 68's new Neighbor on position 2 is now Agent 44.
#
# Agent 70's new Neighbor on position 2 is now Agent 38.
#
# Agent 71's new Neighbor on position 2 is now Agent 58.
#
# Agent 72's new Neighbor on position 2 is now Agent 32.
#
# Agent 76's new Neighbor on position 2 is now Agent 99.
#
# Agent 81's new Neighbor on position 2 is now Agent 94.
#
# Agent 83's new Neighbor on position 2 is now Agent 3.
#
# Agent 85's new Neighbor on position 2 is now Agent 38.
#
# Agent 86's new Neighbor on position 2 is now Agent 60.
#
# Agent 87's new Neighbor on position 2 is now Agent 91.
#
# Agent 90's new Neighbor on position 2 is now Agent 60.
#
# Agent 91's new Neighbor on position 2 is now Agent 80.
#
# Agent 94's new Neighbor on position 2 is now Agent 72.
#
# Agent 97's new Neighbor on position 2 is now Agent 79.
#
# Agent 0's new Neighbor on position 3 is now Agent 18.
#
# Agent 2's new Neighbor on position 3 is now Agent 40.
#
# Agent 4's new Neighbor on position 3 is now Agent 34.
#
# Agent 5's new Neighbor on position 3 is now Agent 36.
#
# Agent 8's new Neighbor on position 3 is now Agent 24.
#
# Agent 10's new Neighbor on position 3 is now Agent 83.
#
# Agent 13's new Neighbor on position 3 is now Agent 23.
#
# Agent 14's new Neighbor on position 3 is now Agent 63.
#
# Agent 17's new Neighbor on position 3 is now Agent 46.
#
# Agent 19's new Neighbor on position 3 is now Agent 97.
#
# Agent 23's new Neighbor on position 3 is now Agent 83.
#
# Agent 26's new Neighbor on position 3 is now Agent 86.
#
# Agent 36's new Neighbor on position 3 is now Agent 41.
#
# Agent 37's new Neighbor on position 3 is now Agent 64.
#
# Agent 38's new Neighbor on position 3 is now Agent 7.
#
# Agent 39's new Neighbor on position 3 is now Agent 43.
#
# Agent 41's new Neighbor on position 3 is now Agent 61.
#
# Agent 42's new Neighbor on position 3 is now Agent 25.
#
# Agent 43's new Neighbor on position 3 is now Agent 25.
#
# Agent 44's new Neighbor on position 3 is now Agent 5.
#
# Agent 47's new Neighbor on position 3 is now Agent 3.
#
# Agent 48's new Neighbor on position 3 is now Agent 6.
#
# Agent 50's new Neighbor on position 3 is now Agent 2.
#
# Agent 54's new Neighbor on position 3 is now Agent 3.
#
# Agent 55's new Neighbor on position 3 is now Agent 48.
#
# Agent 56's new Neighbor on position 3 is now Agent 17.
#
# Agent 58's new Neighbor on position 3 is now Agent 67.
#
# Agent 61's new Neighbor on position 3 is now Agent 43.
#
# Agent 64's new Neighbor on position 3 is now Agent 18.
#
# Agent 66's new Neighbor on position 3 is now Agent 59.
#
# Agent 69's new Neighbor on position 3 is now Agent 60.
#
# Agent 70's new Neighbor on position 3 is now Agent 15.
#
# Agent 71's new Neighbor on position 3 is now Agent 28.
#
# Agent 72's new Neighbor on position 3 is now Agent 78.
#
# Agent 73's new Neighbor on position 3 is now Agent 99.
#
# Agent 76's new Neighbor on position 3 is now Agent 72.
#
# Agent 77's new Neighbor on position 3 is now Agent 6.
#
# Agent 79's new Neighbor on position 3 is now Agent 35.
#
# Agent 80's new Neighbor on position 3 is now Agent 93.
#
# Agent 83's new Neighbor on position 3 is now Agent 27.
#
# Agent 84's new Neighbor on position 3 is now Agent 26.
#
# Agent 85's new Neighbor on position 3 is now Agent 12.
#
# Agent 86's new Neighbor on position 3 is now Agent 14.
#
# Agent 90's new Neighbor on position 3 is now Agent 33.
#
# Agent 93's new Neighbor on position 3 is now Agent 27.
#
# Agent 95's new Neighbor on position 3 is now Agent 74.
#
# Agent 11 got infected.
#
# Agent 12 got infected.
#
# Agent 5 got infected.
#
# Agent 11 died.
#
# Agent 6 got infected.
#
# Agent 4 got infected.
#
# Agent 62 got infected.
#
# Agent 5 died.
#
# Agent 13 got infected.
#
# Agent 10 got infected.
#
# Agent 12 died.
#
# Agent 3 got infected.
#
# Agent 6 got infected.
#
# Agent 34 got infected.
#
# Agent 4 died.
#
# Agent 94 got infected.
#
# Agent 58 got infected.
#
# Agent 6 died.
#
# Agent 11 got infected.
#
# Agent 10 died.
#
# Agent 14 got infected.
#
# Agent 21 got infected.
#
# Agent 23 got infected.
#
# Agent 13 died.
#
# Agent 61 got infected.
#
# Agent 64 got infected.
#
# Agent 60 got infected.
#
# Agent 62 died.
#
# Agent 73 got infected.
#
# Agent 24 got infected.
#
# Agent 70 got infected.
#
# Agent 1 got infected.
#
# Agent 3 died.
#
# Agent 41 got infected.
#
# Agent 49 got infected.
#
# Agent 14 died.
#
# Agent 22 got infected.
#
# Agent 19 got infected.
#
# Agent 21 died.
#
# Agent 22 got infected.
#
# Agent 23 died.
#
# Agent 32 got infected.
#
# Agent 34 died.
#
# Agent 14 got infected.
#
# Agent 67 got infected.
#
# Agent 58 died.
#
# Agent 11 got infected.
#
# Agent 0 got infected.
#
# Agent 58 got infected.
#
# Agent 60 died.
#
# Agent 62 got infected.
#
# Agent 61 died.
#
# Agent 74 got infected.
#
# Agent 18 got infected.
#
# Agent 64 died.
#
# Agent 95 got infected.
#
# Agent 72 got infected.
#
# Agent 94 died.
#
# Agent 1 got infected.
#
# Agent 48 got infected.
#
# Agent 0 died.
#
# Agent 2 got infected.
#
# Agent 99 got infected.
#
# Agent 1 died.
#
# Agent 85 got infected.
#
# Agent 62 got infected.
#
# Agent 16 got infected.
#
# Agent 18 died.
#
# Agent 20 got infected.
#
# Agent 95 got infected.
#
# Agent 97 got infected.
#
# Agent 19 died.
#
# Agent 23 got infected.
#
# Agent 24 got infected.
#
# Agent 22 died.
#
# Agent 23 got infected.
#
# Agent 26 got infected.
#
# Agent 24 died.
#
# Agent 33 got infected.
#
# Agent 31 got infected.
#
# Agent 32 died.
#
# Agent 55 got infected.
#
# Agent 61 got infected.
#
# Agent 41 died.
#
# Agent 50 got infected.
#
# Agent 48 got infected.
#
# Agent 47 got infected.
#
# Agent 49 died.
#
# Agent 60 got infected.
#
# Agent 65 got infected.
#
# Agent 67 died.
#
# Agent 49 got infected.
#
# Agent 15 got infected.
#
# Agent 70 died.
#
# Agent 73 got infected.
#
# Agent 15 got infected.
#
# Agent 32 got infected.
#
# Agent 72 died.
#
# Agent 74 got infected.
#
# Agent 73 died.
#
# Agent 9 got infected.
#
# Agent 72 got infected.
#
# Agent 74 died.
#
# Agent 96 got infected.
#
# Agent 97 got infected.
#
# Agent 95 died.
#
# Agent 67 got infected.
#
# Agent 89 got infected.
#
# Agent 2 died.
#
# Agent 10 got infected.
#
# Agent 11 got infected.
#
# Agent 9 died.
#
# Agent 55 got infected.
#
# Agent 13 got infected.
#
# Agent 15 died.
#
# Agent 66 got infected.
#
# Agent 16 died.
#
# Agent 18 got infected.
#
# Agent 20 died.
#
# Agent 37 got infected.
#
# Agent 25 got infected.
#
# Agent 87 got infected.
#
# Agent 86 got infected.
#
# Agent 26 died.
#
# Agent 37 got infected.
#
# Agent 4 got infected.
#
# Agent 29 got infected.
#
# Agent 31 died.
#
# Agent 34 got infected.
#
# Agent 32 got infected.
#
# Agent 33 died.
#
# Agent 1 got infected.
#
# Agent 47 died.
#
# Agent 48 died.
#
# Agent 50 died.
#
# Agent 55 died.
#
# Agent 66 got infected.
#
# Agent 31 got infected.
#
# Agent 65 died.
#
# Agent 84 got infected.
#
# Agent 38 got infected.
#
# Agent 85 died.
#
# Agent 97 got infected.
#
# Agent 94 got infected.
#
# Agent 96 died.
#
# Agent 43 got infected.
#
# Agent 79 got infected.
#
# Agent 97 died.
#
# Agent 99 died.
#
# Agent 64 got infected.
#
# Agent 23 got infected.
#
# Agent 25 died.
#
# Agent 31 got infected.
#
# Agent 27 got infected.
#
# Agent 29 died.
#
# Agent 79 got infected.
#
# Agent 39 got infected.
#
# Agent 37 died.
#
# Agent 44 got infected.
#
# Agent 38 died.
#
# Agent 45 got infected.
#
# Agent 43 died.
#
# Agent 95 got infected.
#
# Agent 59 got infected.
#
# Agent 66 died.
#
# Agent 31 got infected.
#
# Agent 92 got infected.
#
# Agent 35 got infected.
#
# Agent 79 died.
#
# Agent 83 got infected.
#
# Agent 84 died.
#
# Agent 87 got infected.
#
# Agent 60 got infected.
#
# Agent 14 got infected.
#
# Agent 86 died.
#
# Agent 37 got infected.
#
# Agent 85 got infected.
#
# Agent 87 died.
#
# Agent 89 died.
#
# Agent 44 got infected.
#
# Agent 29 got infected.
#
# Agent 25 got infected.
#
# Agent 27 died.
#
# Agent 32 got infected.
#
# Agent 33 got infected.
#
# Agent 35 died.
#
# Agent 40 got infected.
#
# Agent 43 got infected.
#
# Agent 39 died.
#
# Agent 28 got infected.
#
# ...
#
# Agent 27's new Neighbor on position 1 is now Agent 60.
#
# Agent 28's new Neighbor on position 1 is now Agent 75.
#
# Agent 30's new Neighbor on position 1 is now Agent 72.
#
# Agent 31's new Neighbor on position 1 is now Agent 43.
#
# Agent 32's new Neighbor on position 1 is now Agent 50.
#
# Agent 34's new Neighbor on position 1 is now Agent 21.
#
# Agent 39's new Neighbor on position 1 is now Agent 65.
#
# Agent 40's new Neighbor on position 1 is now Agent 16.
#
# Agent 41's new Neighbor on position 1 is now Agent 56.
#
# Agent 43's new Neighbor on position 1 is now Agent 88.
#
# Agent 44's new Neighbor on position 1 is now Agent 30.
#
# Agent 45's new Neighbor on position 1 is now Agent 42.
#
# Agent 46's new Neighbor on position 1 is now Agent 63.
#
# Agent 47's new Neighbor on position 1 is now Agent 77.
#
# Agent 48's new Neighbor on position 1 is now Agent 58.
#
# Agent 49's new Neighbor on position 1 is now Agent 93.
#
# Agent 52's new Neighbor on position 1 is now Agent 41.
#
# Agent 54's new Neighbor on position 1 is now Agent 69.
#
# Agent 56's new Neighbor on position 1 is now Agent 7.
#
# Agent 57's new Neighbor on position 1 is now Agent 63.
#
# Agent 58's new Neighbor on position 1 is now Agent 67.
#
# Agent 59's new Neighbor on position 1 is now Agent 9.
#
# Agent 61's new Neighbor on position 1 is now Agent 84.
#
# Agent 62's new Neighbor on position 1 is now Agent 3.
#
# Agent 64's new Neighbor on position 1 is now Agent 22.
#
# Agent 65's new Neighbor on position 1 is now Agent 73.
#
# Agent 66's new Neighbor on position 1 is now Agent 26.
#
# Agent 67's new Neighbor on position 1 is now Agent 34.
#
# Agent 68's new Neighbor on position 1 is now Agent 2.
#
# Agent 69's new Neighbor on position 1 is now Agent 85.
#
# Agent 70's new Neighbor on position 1 is now Agent 21.
#
# Agent 72's new Neighbor on position 1 is now Agent 80.
#
# Agent 73's new Neighbor on position 1 is now Agent 54.
#
# Agent 75's new Neighbor on position 1 is now Agent 39.
#
# Agent 77's new Neighbor on position 1 is now Agent 1.
#
# Agent 78's new Neighbor on position 1 is now Agent 62.
#
# Agent 79's new Neighbor on position 1 is now Agent 90.
#
# Agent 80's new Neighbor on position 1 is now Agent 94.
#
# Agent 81's new Neighbor on position 1 is now Agent 5.
#
# Agent 82's new Neighbor on position 1 is now Agent 38.
#
# Agent 83's new Neighbor on position 1 is now Agent 38.
#
# Agent 84's new Neighbor on position 1 is now Agent 54.
#
# Agent 85's new Neighbor on position 1 is now Agent 60.
#
# Agent 86's new Neighbor on position 1 is now Agent 24.
#
# Agent 87's new Neighbor on position 1 is now Agent 27.
#
# Agent 88's new Neighbor on position 1 is now Agent 10.
#
# Agent 89's new Neighbor on position 1 is now Agent 52.
#
# Agent 90's new Neighbor on position 1 is now Agent 38.
#
# Agent 92's new Neighbor on position 1 is now Agent 42.
#
# Agent 93's new Neighbor on position 1 is now Agent 81.
#
# Agent 94's new Neighbor on position 1 is now Agent 78.
#
# Agent 95's new Neighbor on position 1 is now Agent 6.
#
# Agent 96's new Neighbor on position 1 is now Agent 11.
#
# Agent 98's new Neighbor on position 1 is now Agent 36.
#
# Agent 0's new Neighbor on position 2 is now Agent 57.
#
# Agent 1's new Neighbor on position 2 is now Agent 66.
#
# Agent 2's new Neighbor on position 2 is now Agent 49.
#
# Agent 3's new Neighbor on position 2 is now Agent 85.
#
# Agent 4's new Neighbor on position 2 is now Agent 86.
#
# Agent 5's new Neighbor on position 2 is now Agent 49.
#
# Agent 6's new Neighbor on position 2 is now Agent 64.
#
# Agent 7's new Neighbor on position 2 is now Agent 41.
#
# Agent 8's new Neighbor on position 2 is now Agent 42.
#
# Agent 10's new Neighbor on position 2 is now Agent 19.
#
# Agent 11's new Neighbor on position 2 is now Agent 39.
#
# Agent 12's new Neighbor on position 2 is now Agent 39.
#
# Agent 14's new Neighbor on position 2 is now Agent 42.
#
# Agent 15's new Neighbor on position 2 is now Agent 61.
#
# Agent 16's new Neighbor on position 2 is now Agent 99.
#
# Agent 17's new Neighbor on position 2 is now Agent 89.
#
# Agent 19's new Neighbor on position 2 is now Agent 30.
#
# Agent 21's new Neighbor on position 2 is now Agent 43.
#
# Agent 22's new Neighbor on position 2 is now Agent 91.
#
# Agent 24's new Neighbor on position 2 is now Agent 91.
#
# Agent 26's new Neighbor on position 2 is now Agent 46.
#
# Agent 28's new Neighbor on position 2 is now Agent 23.
#
# Agent 30's new Neighbor on position 2 is now Agent 33.
#
# Agent 33's new Neighbor on position 2 is now Agent 54.
#
# Agent 34's new Neighbor on position 2 is now Agent 4.
#
# Agent 35's new Neighbor on position 2 is now Agent 18.
#
# Agent 36's new Neighbor on position 2 is now Agent 5.
#
# Agent 37's new Neighbor on position 2 is now Agent 47.
#
# Agent 38's new Neighbor on position 2 is now Agent 5.
#
# Agent 39's new Neighbor on position 2 is now Agent 27.
#
# Agent 40's new Neighbor on position 2 is now Agent 43.
#
# Agent 41's new Neighbor on position 2 is now Agent 19.
#
# Agent 42's new Neighbor on position 2 is now Agent 42.
#
# Agent 43's new Neighbor on position 2 is now Agent 25.
#
# Agent 45's new Neighbor on position 2 is now Agent 6.
#
# Agent 47's new Neighbor on position 2 is now Agent 31.
#
# Agent 49's new Neighbor on position 2 is now Agent 2.
#
# Agent 50's new Neighbor on position 2 is now Agent 39.
#
# Agent 51's new Neighbor on position 2 is now Agent 98.
#
# Agent 52's new Neighbor on position 2 is now Agent 35.
#
# Agent 53's new Neighbor on position 2 is now Agent 33.
#
# Agent 54's new Neighbor on position 2 is now Agent 92.
#
# Agent 55's new Neighbor on position 2 is now Agent 2.
#
# Agent 56's new Neighbor on position 2 is now Agent 88.
#
# Agent 57's new Neighbor on position 2 is now Agent 68.
#
# Agent 58's new Neighbor on position 2 is now Agent 73.
#
# Agent 59's new Neighbor on position 2 is now Agent 4.
#
# Agent 60's new Neighbor on position 2 is now Agent 97.
#
# Agent 61's new Neighbor on position 2 is now Agent 54.
#
# Agent 63's new Neighbor on position 2 is now Agent 93.
#
# Agent 64's new Neighbor on position 2 is now Agent 84.
#
# Agent 66's new Neighbor on position 2 is now Agent 39.
#
# Agent 67's new Neighbor on position 2 is now Agent 50.
#
# Agent 68's new Neighbor on position 2 is now Agent 98.
#
# Agent 69's new Neighbor on position 2 is now Agent 95.
#
# Agent 71's new Neighbor on position 2 is now Agent 63.
#
# Agent 72's new Neighbor on position 2 is now Agent 22.
#
# Agent 73's new Neighbor on position 2 is now Agent 91.
#
# Agent 74's new Neighbor on position 2 is now Agent 28.
#
# Agent 75's new Neighbor on position 2 is now Agent 33.
#
# Agent 76's new Neighbor on position 2 is now Agent 0.
#
# Agent 77's new Neighbor on position 2 is now Agent 38.
#
# Agent 78's new Neighbor on position 2 is now Agent 55.
#
# Agent 79's new Neighbor on position 2 is now Agent 28.
#
# Agent 80's new Neighbor on position 2 is now Agent 90.
#
# Agent 82's new Neighbor on position 2 is now Agent 33.
#
# Agent 84's new Neighbor on position 2 is now Agent 29.
#
# Agent 85's new Neighbor on position 2 is now Agent 89.
#
# Agent 86's new Neighbor on position 2 is now Agent 47.
#
# Agent 87's new Neighbor on position 2 is now Agent 17.
#
# Agent 88's new Neighbor on position 2 is now Agent 43.
#
# Agent 89's new Neighbor on position 2 is now Agent 49.
#
# Agent 90's new Neighbor on position 2 is now Agent 51.
#
# Agent 91's new Neighbor on position 2 is now Agent 99.
#
# Agent 93's new Neighbor on position 2 is now Agent 10.
#
# Agent 94's new Neighbor on position 2 is now Agent 7.
#
# Agent 95's new Neighbor on position 2 is now Agent 12.
#
# Agent 96's new Neighbor on position 2 is now Agent 75.
#
# Agent 97's new Neighbor on position 2 is now Agent 20.
#
# Agent 98's new Neighbor on position 2 is now Agent 48.
#
# Agent 99's new Neighbor on position 2 is now Agent 41.
#
# Agent 0's new Neighbor on position 3 is now Agent 58.
#
# Agent 1's new Neighbor on position 3 is now Agent 22.
#
# Agent 2's new Neighbor on position 3 is now Agent 8.
#
# Agent 4's new Neighbor on position 3 is now Agent 50.
#
# Agent 5's new Neighbor on position 3 is now Agent 16.
#
# Agent 6's new Neighbor on position 3 is now Agent 12.
#
# Agent 7's new Neighbor on position 3 is now Agent 85.
#
# Agent 8's new Neighbor on position 3 is now Agent 2.
#
# Agent 9's new Neighbor on position 3 is now Agent 81.
#
# Agent 10's new Neighbor on position 3 is now Agent 38.
#
# Agent 11's new Neighbor on position 3 is now Agent 83.
#
# Agent 12's new Neighbor on position 3 is now Agent 46.
#
# Agent 13's new Neighbor on position 3 is now Agent 72.
#
# Agent 14's new Neighbor on position 3 is now Agent 82.
#
# Agent 15's new Neighbor on position 3 is now Agent 30.
#
# Agent 16's new Neighbor on position 3 is now Agent 82.
#
# Agent 17's new Neighbor on position 3 is now Agent 16.
#
# Agent 18's new Neighbor on position 3 is now Agent 46.
#
# Agent 19's new Neighbor on position 3 is now Agent 43.
#
# Agent 21's new Neighbor on position 3 is now Agent 8.
#
# Agent 23's new Neighbor on position 3 is now Agent 91.
#
# Agent 24's new Neighbor on position 3 is now Agent 3.
#
# Agent 25's new Neighbor on position 3 is now Agent 36.
#
# Agent 27's new Neighbor on position 3 is now Agent 30.
#
# Agent 30's new Neighbor on position 3 is now Agent 40.
#
# Agent 33's new Neighbor on position 3 is now Agent 93.
#
# Agent 34's new Neighbor on position 3 is now Agent 79.
#
# Agent 35's new Neighbor on position 3 is now Agent 76.
#
# Agent 37's new Neighbor on position 3 is now Agent 3.
#
# Agent 39's new Neighbor on position 3 is now Agent 93.
#
# Agent 41's new Neighbor on position 3 is now Agent 49.
#
# Agent 42's new Neighbor on position 3 is now Agent 68.
#
# Agent 43's new Neighbor on position 3 is now Agent 18.
#
# Agent 45's new Neighbor on position 3 is now Agent 66.
#
# Agent 46's new Neighbor on position 3 is now Agent 71.
#
# Agent 47's new Neighbor on position 3 is now Agent 19.
#
# Agent 48's new Neighbor on position 3 is now Agent 79.
#
# Agent 49's new Neighbor on position 3 is now Agent 10.
#
# Agent 51's new Neighbor on position 3 is now Agent 28.
#
# Agent 52's new Neighbor on position 3 is now Agent 46.
#
# Agent 53's new Neighbor on position 3 is now Agent 72.
#
# Agent 54's new Neighbor on position 3 is now Agent 43.
#
# Agent 55's new Neighbor on position 3 is now Agent 20.
#
# Agent 56's new Neighbor on position 3 is now Agent 64.
#
# Agent 58's new Neighbor on position 3 is now Agent 82.
#
# Agent 59's new Neighbor on position 3 is now Agent 78.
#
# Agent 60's new Neighbor on position 3 is now Agent 30.
#
# Agent 61's new Neighbor on position 3 is now Agent 27.
#
# Agent 63's new Neighbor on position 3 is now Agent 98.
#
# Agent 65's new Neighbor on position 3 is now Agent 9.
#
# Agent 66's new Neighbor on position 3 is now Agent 63.
#
# Agent 67's new Neighbor on position 3 is now Agent 44.
#
# Agent 68's new Neighbor on position 3 is now Agent 54.
#
# Agent 69's new Neighbor on position 3 is now Agent 25.
#
# Agent 70's new Neighbor on position 3 is now Agent 20.
#
# Agent 71's new Neighbor on position 3 is now Agent 44.
#
# Agent 73's new Neighbor on position 3 is now Agent 65.
#
# Agent 74's new Neighbor on position 3 is now Agent 75.
#
# Agent 75's new Neighbor on position 3 is now Agent 45.
#
# Agent 77's new Neighbor on position 3 is now Agent 20.
#
# Agent 79's new Neighbor on position 3 is now Agent 5.
#
# Agent 80's new Neighbor on position 3 is now Agent 35.
#
# Agent 81's new Neighbor on position 3 is now Agent 43.
#
# Agent 82's new Neighbor on position 3 is now Agent 99.
#
# Agent 83's new Neighbor on position 3 is now Agent 44.
#
# Agent 84's new Neighbor on position 3 is now Agent 44.
#
# Agent 86's new Neighbor on position 3 is now Agent 50.
#
# Agent 88's new Neighbor on position 3 is now Agent 6.
#
# Agent 90's new Neighbor on position 3 is now Agent 27.
#
# Agent 91's new Neighbor on position 3 is now Agent 94.
#
# Agent 92's new Neighbor on position 3 is now Agent 69.
#
# Agent 93's new Neighbor on position 3 is now Agent 68.
#
# Agent 94's new Neighbor on position 3 is now Agent 25.
#
# Agent 97's new Neighbor on position 3 is now Agent 25.
#
# Agent 98's new Neighbor on position 3 is now Agent 54.
#
# Agent 99's new Neighbor on position 3 is now Agent 77.
#
# Agent 73 got infected.
#
# Agent 76 got infected.
#
# Agent 54 got infected.
#
# Agent 91 got infected.
#
# Agent 73 died.
#
# Agent 69 got infected.
#
# Agent 43 got infected.
#
# Agent 54 died.
#
# Agent 75 got infected.
#
# Agent 74 got infected.
#
# Agent 76 died.
#
# Agent 90 got infected.
#
# Agent 99 got infected.
#
# Agent 94 got infected.
#
# Agent 91 died.
#
# Agent 88 got infected.
#
# Agent 18 got infected.
#
# Agent 43 died.
#
# Agent 95 got infected.
#
# Agent 25 got infected.
#
# Agent 69 died.
#
# Agent 83 got infected.
#
# Agent 74 died.
#
# Agent 75 died.
#
# Agent 13 got infected.
#
# Agent 90 died.
#
# Agent 78 got infected.
#
# Agent 7 got infected.
#
# Agent 94 died.
#
# Agent 41 got infected.
#
# Agent 77 got infected.
#
# Agent 99 died.
#
# Agent 7 died.
#
# Agent 14 got infected.
#
# Agent 64 got infected.
#
# Agent 15 got infected.
#
# Agent 72 got infected.
#
# Agent 13 died.
#
# Agent 12 got infected.
#
# Agent 18 died.
#
# Agent 87 got infected.
#
# Agent 25 died.
#
# Agent 86 got infected.
#
# Agent 56 got infected.
#
# Agent 49 got infected.
#
# Agent 41 died.
#
# Agent 95 got infected.
#
# Agent 38 got infected.
#
# Agent 77 died.
#
# Agent 78 died.
#
# Agent 85 got infected.
#
# Agent 83 died.
#
# Agent 94 got infected.
#
# Agent 43 got infected.
#
# Agent 88 died.
#
# Agent 96 got infected.
#
# Agent 95 died.
#
# Agent 73 got infected.
#
# Agent 46 got infected.
#
# Agent 12 died.
#
# Agent 14 died.
#
# Agent 69 got infected.
#
# Agent 49 got infected.
#
# Agent 30 got infected.
#
# Agent 15 died.
#
# Agent 37 got infected.
#
# Agent 38 died.
#
# Agent 19 got infected.
#
# Agent 93 got infected.
#
# Agent 10 got infected.
#
# Agent 49 died.
#
# Agent 7 got infected.
#
# Agent 88 got infected.
#
# Agent 64 got infected.
#
# Agent 56 died.
#
# Agent 84 got infected.
#
# Agent 64 died.
#
# Agent 70 got infected.
#
# Agent 72 died.
#
# Agent 89 got infected.
#
# Agent 85 died.
#
# Agent 24 got infected.
#
# Agent 47 got infected.
#
# Agent 86 died.
#
# Agent 45 got infected.
#
# Agent 17 got infected.
#
# Agent 85 got infected.
#
# Agent 87 died.
#
# Agent 91 got infected.
#
# Agent 11 got infected.
#
# Agent 96 died.
#
# Agent 10 died.
#
# Agent 39 got infected.
#
# Agent 83 got infected.
#
# Agent 11 died.
#
# Agent 89 got infected.
#
# Agent 17 died.
#
# Agent 20 got infected.
#
# Agent 4 got infected.
#
# Agent 30 got infected.
#
# Agent 19 died.
#
# Agent 24 died.
#
# Agent 31 got infected.
#
# Agent 33 got infected.
#
# Agent 40 got infected.
#
# Agent 30 died.
#
# Agent 5 got infected.
#
# Agent 47 got infected.
#
# Agent 37 died.
#
# Agent 6 got infected.
#
# Agent 45 died.
#
# Agent 39 got infected.
#
# Agent 48 got infected.
#
# Agent 71 got infected.
#
# Agent 46 died.
#
# Agent 77 got infected.
#
# Agent 19 got infected.
#
# Agent 47 died.
#
# Agent 20 got infected.
#
# Agent 70 died.
#
# Agent 96 got infected.
#
# Agent 44 got infected.
#
# Agent 84 died.
#
# Agent 51 got infected.
#
# Agent 89 died.
#
# Agent 10 got infected.
#
# Agent 93 died.
#
# Agent 63 got infected.
#
# Agent 4 died.
#
# Agent 5 died.
#
# Agent 64 got infected.
#
# Agent 6 died.
#
# Agent 21 got infected.
#
# Agent 19 got infected.
#
# Agent 22 got infected.
#
# Agent 20 died.
#
# Agent 33 got infected.
#
# Agent 31 died.
#
# Agent 54 got infected.
#
# Agent 93 got infected.
#
# Agent 33 died.
#
# Agent 65 got infected.
#
# Agent 93 got infected.
#
# Agent 39 died.
#
# Agent 16 got infected.
#
# Agent 40 died.
#
# Agent 63 got infected.
#
# Agent 30 got infected.
#
# Agent 44 died.
#
# Agent 48 died.
#
# Agent 51 died.
#
# Agent 34 got infected.
#
# Agent 63 got infected.
#
# Agent 71 died.
#
# Agent 99 got infected.
#
# Agent 82 got infected.
#
# Agent 16 died.
#
# Agent 4 got infected.
#
# Agent 79 got infected.
#
# Agent 21 died.
#
# Agent 99 got infected.
#
# Agent 17 got infected.
#
# Agent 20 got infected.
#
# Agent 22 died.
#
# Agent 4 got infected.
#
# Agent 79 got infected.
#
# Agent 34 died.
#
# Agent 64 got infected.
#
# Agent 93 got infected.
#
# Agent 63 died.
#
# Agent 9 got infected.
#
# Agent 65 died.
#
# Agent 79 got infected.
#
# Agent 81 got infected.
#
# Agent 9 died.
#
# Agent 90 got infected.
#
# Agent 5 got infected.
#
# Agent 79 died.
#
# Agent 38 got infected.
#
# Agent 33 got infected.
#
# Agent 82 died.
#
# Agent 43 got infected.
#
# Agent 81 died.
# 216it [00:01, 145.53it/s]IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
import pandas as pd

results_df = pd.DataFrame(results)
display(results_df)
# Out:
#        RunId  iteration  Step    N  k    p    r  AgentID  Infected
# 0          0         -1   100  100  4  0.1  0.5        0     False
# 1          0         -1   100  100  4  0.1  0.5        1     False
# 2          0         -1   100  100  4  0.1  0.5        2     False
# 3          0         -1   100  100  4  0.1  0.5        3     False
# 4          0         -1   100  100  4  0.1  0.5        4     False
# ...      ...        ...   ...  ... ..  ...  ...      ...       ...
# 24995    249          3   100  100  4  1.0  0.5       95      True
# 24996    249          3   100  100  4  1.0  0.5       96      True
# 24997    249          3   100  100  4  1.0  0.5       97      True
# 24998    249          3   100  100  4  1.0  0.5       98      True
# 24999    249          3   100  100  4  1.0  0.5       99      True
#
# [25000 rows x 9 columns]

# %%
rearranging_df = results_df.groupby(by=["p"]).sum()
print(rearranging_df)
df_cutted = pd.DataFrame(rearranging_df, columns = ["Infected"])
print(df_cutted)
boxplot = df_cutted.boxplot(column = ["Infected"], by='p', showmeans = True)
# Out:
#       RunId  iteration    Step       N      k       r  AgentID  Infected
# p
# 0.1  300000       2500  250000  250000  10000  1250.0   123750      1176
# 0.2  302500       2500  250000  250000  10000  1250.0   123750      1700
# 0.3  305000       2500  250000  250000  10000  1250.0   123750      1611
# 0.4  307500       2500  250000  250000  10000  1250.0   123750      1746
# 0.5  310000       2500  250000  250000  10000  1250.0   123750      2005
# 0.6  312500       2500  250000  250000  10000  1250.0   123750      1910
# 0.7  315000       2500  250000  250000  10000  1250.0   123750      1767
# 0.8  317500       2500  250000  250000  10000  1250.0   123750      1751
# 0.9  320000       2500  250000  250000  10000  1250.0   123750      2010
# 1.0  322500       2500  250000  250000  10000  1250.0   123750      1930
#      Infected
# p
# 0.1      1176
# 0.2      1700
# 0.3      1611
# 0.4      1746
# 0.5      2005
# 0.6      1910
# 0.7      1767
# 0.8      1751
# 0.9      2010
# 1.0      1930
